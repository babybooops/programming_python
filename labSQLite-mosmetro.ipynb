# %%
from pathlib import Path

from sqlalchemy import create_engine, String, Integer, Column, Unicode, ForeignKey, URL, select, and_
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, declarative_base, Session, relationship
import pandas as pd

# %%
# задание базы данных
engine = create_engine("sqlite:///mosmetro.db", echo=False)

# %%
Base = declarative_base() # задание родительского класса, чтобы описывать каждую таблицу как класс

# создание таблиц
class Line(Base):
    __tablename__ = 'line'

    id = Column(Integer, primary_key=True)
    line = Column(Unicode)
    station = relationship('Station', uselist=False, back_populates='line')

    def __repr__(self) -> str:
        return f"Line name: {self.line}"


class District(Base):
    __tablename__ = 'district'

    id = Column(Integer, primary_key=True, autoincrement='auto', index=True)
    district = Column(Unicode)
    station = relationship('Station', uselist=False, back_populates='district')

    def __repr__(self) -> str:
        return f"District name: {self.district}"


class MCD(Base):
    __tablename__ = 'mcd'

    id = Column(Integer, primary_key=True, autoincrement='auto', index=True)
    name = Column(Unicode)
    global_id = Column(Integer)
    station = relationship('Station', uselist=False, back_populates='mcd')

    def __repr__(self) -> str:
        return f"MCD station name: {self.name}"


class AeroExpress(Base):
    __tablename__ = 'aeroexpress'

    id = Column(Integer, primary_key=True, autoincrement='auto', index=True)
    name = Column(Unicode)
    global_id = Column(Integer)
    station = relationship('Station', uselist=False, back_populates='aeroexpress')

    def __repr__(self) -> str:
        return f"Aeroexpress station name: {self.name}"


class RailwayStation(Base):
    __tablename__ = 'railway'

    id = Column(Integer, primary_key=True, autoincrement='auto', index=True)
    name = Column(Unicode)
    global_id = Column(Integer)
    station = relationship('Station', uselist=False, back_populates='railway')

    def __repr__(self) -> str:
        return f"Railway station name: {self.name}"


class Station(Base):
    __tablename__ = 'station'

    id = Column(Integer, primary_key=True, autoincrement='auto', index=True)
    dataset_id = Column(Integer)
    station = Column(Unicode)
    line_id = mapped_column(ForeignKey("line.id", ondelete='CASCADE'), nullable=False)
    line = relationship("Line", back_populates="station")
    adm_area = Column(Unicode)
    district_id = mapped_column(ForeignKey("district.id", ondelete='CASCADE'), nullable=False)
    district = relationship("District", back_populates="station")
    mcd_id = mapped_column(ForeignKey("mcd.id", ondelete='CASCADE'))
    mcd = relationship("MCD", back_populates="station")
    aeroexpress_id = mapped_column(ForeignKey("aeroexpress.id", ondelete='CASCADE'))
    aeroexpress = relationship("AeroExpress", back_populates="station")
    railway_id = mapped_column(ForeignKey("railway.id", ondelete='CASCADE'))
    railway = relationship("RailwayStation", back_populates="station")
    status = Column(Unicode)
    global_id = Column(Integer)

    def __repr__(self) -> str:
        return f"Station name: {self.station}"

# %%
"""Функция для создания бд"""
def json_to_db_metro(path_to_json: str) -> None:
    Base.metadata.create_all(engine) # создание таблиц на основе классов от родительского класса Base
    data = pd.read_json(Path(path_to_json), orient='records', encoding='utf-8')
    with Session(engine) as session:
        for row in data['Line'].unique():
            line = Line(
                line=row
            )
            session.add(line)
            session.commit()
    with Session(engine) as session:
        for row in data['District'].unique():
            district = District(
                district=row
            )
            session.add(district)
            session.commit()
    with Session(engine) as session:
        for i, row in data.loc[data['MCDStation'].str.len() != 0].iterrows():
            mcd = MCD(
                name=row["MCDStation"]['value'],
                global_id=row["MCDStation"]['global_id']
            )
            session.add(mcd)
            session.commit()
    with Session(engine) as session:
        for i, row in data.loc[data['AeroexpressStation'].str.len() != 0].iterrows():
            aeroexpress = AeroExpress(
                name=row["AeroexpressStation"]['value'],
                global_id=row["AeroexpressStation"]['global_id']
            )
            session.add(aeroexpress)
            session.commit()
    with Session(engine) as session:
        for i, row in data.loc[data['RailwayStation'].str.len() != 0].iterrows():
            railway = RailwayStation(
                name=row["RailwayStation"]['value'],
                global_id=row["RailwayStation"]['global_id']
            )
            session.add(railway)
            session.commit()
    with Session(engine) as session:
        for i, row in data.iterrows():
            line_id = select(Line.id).where(Line.line == row['Line'])
            print(line_id)
            district_id = select(District.id).where(District.district == row['District'])
            if isinstance(row['MCDStation'], dict):
                mcd_id = select(MCD.id).where(MCD.name == row['MCDStation']['value'])
            else:
                mcd_id = None
            if isinstance(row['AeroexpressStation'], dict):
                aeroexpress_id = select(AeroExpress.id).where(AeroExpress.name == row['AeroexpressStation']['value'])
            else:
                aeroexpress_id = None
            if isinstance(row['RailwayStation'], dict):
                railway_id = select(RailwayStation.id).where(RailwayStation.name == row['RailwayStation']['value'])
            else:
                railway_id = None
            station = Station(
                dataset_id=row['ID'],
                station=row['Station'],
                line_id=line_id,
                adm_area=row['AdmArea'],
                district_id=district_id,
                mcd_id=mcd_id,
                aeroexpress_id=aeroexpress_id,
                railway_id=railway_id,
                status=row['ObjectStatus'],
                global_id=row['global_id']
            )
            session.add(station)
            session.flush() # обновление связей
            session.commit()

# %%
json_to_db_metro('mosmetro.json')
# Out:
# 2023-06-16 00:32:32,262 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,263 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("line")
# 2023-06-16 00:32:32,264 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,266 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("line")
# 2023-06-16 00:32:32,267 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,268 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("district")
# 2023-06-16 00:32:32,270 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,271 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("district")
# 2023-06-16 00:32:32,272 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,273 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("mcd")
# 2023-06-16 00:32:32,274 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,276 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("mcd")
# 2023-06-16 00:32:32,277 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,278 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("aeroexpress")
# 2023-06-16 00:32:32,279 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,280 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("aeroexpress")
# 2023-06-16 00:32:32,282 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,283 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("railway")
# 2023-06-16 00:32:32,283 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,284 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("railway")
# 2023-06-16 00:32:32,285 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,286 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("station")
# 2023-06-16 00:32:32,287 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,288 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("station")
# 2023-06-16 00:32:32,288 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-06-16 00:32:32,290 INFO sqlalchemy.engine.Engine
# CREATE TABLE line (
# 	id INTEGER NOT NULL,
# 	line VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-06-16 00:32:32,291 INFO sqlalchemy.engine.Engine [no key 0.00075s] ()
# 2023-06-16 00:32:32,300 INFO sqlalchemy.engine.Engine
# CREATE TABLE district (
# 	id INTEGER NOT NULL,
# 	district VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-06-16 00:32:32,301 INFO sqlalchemy.engine.Engine [no key 0.00099s] ()
# 2023-06-16 00:32:32,308 INFO sqlalchemy.engine.Engine CREATE INDEX ix_district_id ON district (id)
# 2023-06-16 00:32:32,309 INFO sqlalchemy.engine.Engine [no key 0.00106s] ()
# 2023-06-16 00:32:32,317 INFO sqlalchemy.engine.Engine
# CREATE TABLE mcd (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	global_id INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-06-16 00:32:32,318 INFO sqlalchemy.engine.Engine [no key 0.00100s] ()
# 2023-06-16 00:32:32,324 INFO sqlalchemy.engine.Engine CREATE INDEX ix_mcd_id ON mcd (id)
# 2023-06-16 00:32:32,325 INFO sqlalchemy.engine.Engine [no key 0.00092s] ()
# 2023-06-16 00:32:32,334 INFO sqlalchemy.engine.Engine
# CREATE TABLE aeroexpress (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	global_id INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-06-16 00:32:32,334 INFO sqlalchemy.engine.Engine [no key 0.00086s] ()
# 2023-06-16 00:32:32,341 INFO sqlalchemy.engine.Engine CREATE INDEX ix_aeroexpress_id ON aeroexpress (id)
# 2023-06-16 00:32:32,341 INFO sqlalchemy.engine.Engine [no key 0.00091s] ()
# 2023-06-16 00:32:32,349 INFO sqlalchemy.engine.Engine
# CREATE TABLE railway (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	global_id INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-06-16 00:32:32,350 INFO sqlalchemy.engine.Engine [no key 0.00112s] ()
# 2023-06-16 00:32:32,357 INFO sqlalchemy.engine.Engine CREATE INDEX ix_railway_id ON railway (id)
# 2023-06-16 00:32:32,358 INFO sqlalchemy.engine.Engine [no key 0.00110s] ()
# 2023-06-16 00:32:32,366 INFO sqlalchemy.engine.Engine
# CREATE TABLE station (
# 	id INTEGER NOT NULL,
# 	dataset_id INTEGER,
# 	station VARCHAR,
# 	line_id INTEGER NOT NULL,
# 	adm_area VARCHAR,
# 	district_id INTEGER NOT NULL,
# 	mcd_id INTEGER,
# 	aeroexpress_id INTEGER,
# 	railway_id INTEGER,
# 	status VARCHAR,
# 	global_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(line_id) REFERENCES line (id) ON DELETE CASCADE,
# 	FOREIGN KEY(district_id) REFERENCES district (id) ON DELETE CASCADE,
# 	FOREIGN KEY(mcd_id) REFERENCES mcd (id) ON DELETE CASCADE,
# 	FOREIGN KEY(aeroexpress_id) REFERENCES aeroexpress (id) ON DELETE CASCADE,
# 	FOREIGN KEY(railway_id) REFERENCES railway (id) ON DELETE CASCADE
# )
#
#
# 2023-06-16 00:32:32,367 INFO sqlalchemy.engine.Engine [no key 0.00109s] ()
# 2023-06-16 00:32:32,374 INFO sqlalchemy.engine.Engine CREATE INDEX ix_station_id ON station (id)
# 2023-06-16 00:32:32,376 INFO sqlalchemy.engine.Engine [no key 0.00126s] ()
# 2023-06-16 00:32:32,383 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,511 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,513 INFO sqlalchemy.engine.Engine [generated in 0.00166s] ('Калининская линия',)
# 2023-06-16 00:32:32,516 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,524 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,527 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,528 INFO sqlalchemy.engine.Engine [cached since 0.01691s ago] ('Калужско-Рижская линия',)
# 2023-06-16 00:32:32,531 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,540 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,542 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,542 INFO sqlalchemy.engine.Engine [cached since 0.031s ago] ('Арбатско-Покровская линия',)
# 2023-06-16 00:32:32,546 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,552 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,553 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,553 INFO sqlalchemy.engine.Engine [cached since 0.0419s ago] ('Большая кольцевая линия',)
# 2023-06-16 00:32:32,558 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,566 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,566 INFO sqlalchemy.engine.Engine [cached since 0.05515s ago] ('Бутовская линия Лёгкого метро',)
# 2023-06-16 00:32:32,568 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,575 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,576 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,577 INFO sqlalchemy.engine.Engine [cached since 0.0659s ago] ('Замоскворецкая линия',)
# 2023-06-16 00:32:32,580 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,586 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,587 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,588 INFO sqlalchemy.engine.Engine [cached since 0.07659s ago] ('Люблинско-Дмитровская линия',)
# 2023-06-16 00:32:32,591 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,597 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,598 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,599 INFO sqlalchemy.engine.Engine [cached since 0.08812s ago] ('Солнцевская линия',)
# 2023-06-16 00:32:32,601 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,607 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,608 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,608 INFO sqlalchemy.engine.Engine [cached since 0.09709s ago] ('Серпуховско-Тимирязевская линия',)
# 2023-06-16 00:32:32,610 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,619 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,621 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,621 INFO sqlalchemy.engine.Engine [cached since 0.1097s ago] ('Московская монорельсовая транспортная система',)
# 2023-06-16 00:32:32,623 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,631 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,632 INFO sqlalchemy.engine.Engine [cached since 0.1206s ago] ('Таганско-Краснопресненская линия',)
# 2023-06-16 00:32:32,634 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,641 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,643 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,645 INFO sqlalchemy.engine.Engine [cached since 0.1341s ago] ('Некрасовская линия',)
# 2023-06-16 00:32:32,648 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,656 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,657 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,658 INFO sqlalchemy.engine.Engine [cached since 0.1467s ago] ('Сокольническая линия',)
# 2023-06-16 00:32:32,661 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,667 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,668 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,669 INFO sqlalchemy.engine.Engine [cached since 0.1575s ago] ('Кольцевая линия',)
# 2023-06-16 00:32:32,671 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,680 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,681 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,682 INFO sqlalchemy.engine.Engine [cached since 0.1705s ago] ('Филёвская линия',)
# 2023-06-16 00:32:32,684 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,691 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,693 INFO sqlalchemy.engine.Engine INSERT INTO line (line) VALUES (?)
# 2023-06-16 00:32:32,693 INFO sqlalchemy.engine.Engine [cached since 0.1821s ago] ('Московское центральное кольцо',)
# 2023-06-16 00:32:32,696 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,703 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,706 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,707 INFO sqlalchemy.engine.Engine [generated in 0.00197s] ('район Замоскворечье',)
# 2023-06-16 00:32:32,711 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,718 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,719 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,719 INFO sqlalchemy.engine.Engine [cached since 0.01365s ago] ('район Северное Медведково',)
# 2023-06-16 00:32:32,725 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,732 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,733 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,734 INFO sqlalchemy.engine.Engine [cached since 0.02833s ago] ('район Измайлово',)
# 2023-06-16 00:32:32,736 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,746 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,747 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,748 INFO sqlalchemy.engine.Engine [cached since 0.04272s ago] ('Обручевский район',)
# 2023-06-16 00:32:32,751 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,758 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,759 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,760 INFO sqlalchemy.engine.Engine [cached since 0.05426s ago] ('район Зюзино',)
# 2023-06-16 00:32:32,762 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,767 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,768 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,771 INFO sqlalchemy.engine.Engine [cached since 0.06564s ago] ('район Южное Бутово',)
# 2023-06-16 00:32:32,775 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,790 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,792 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,792 INFO sqlalchemy.engine.Engine [cached since 0.0871s ago] ('район Кузьминки',)
# 2023-06-16 00:32:32,795 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,804 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,806 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,807 INFO sqlalchemy.engine.Engine [cached since 0.1019s ago] ('Донской район',)
# 2023-06-16 00:32:32,811 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,817 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,818 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,819 INFO sqlalchemy.engine.Engine [cached since 0.1133s ago] ('район Арбат',)
# 2023-06-16 00:32:32,821 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,827 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,828 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,828 INFO sqlalchemy.engine.Engine [cached since 0.1225s ago] ('Тимирязевский район',)
# 2023-06-16 00:32:32,830 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,836 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,837 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,838 INFO sqlalchemy.engine.Engine [cached since 0.1322s ago] ('Останкинский район',)
# 2023-06-16 00:32:32,840 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,847 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,848 INFO sqlalchemy.engine.Engine [cached since 0.1429s ago] ('Тверской район',)
# 2023-06-16 00:32:32,851 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,857 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,858 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,859 INFO sqlalchemy.engine.Engine [cached since 0.1534s ago] ('Бутырский район',)
# 2023-06-16 00:32:32,861 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,868 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,870 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,871 INFO sqlalchemy.engine.Engine [cached since 0.1653s ago] ('район Черёмушки',)
# 2023-06-16 00:32:32,874 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,881 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,882 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,883 INFO sqlalchemy.engine.Engine [cached since 0.1773s ago] ('Нижегородский район',)
# 2023-06-16 00:32:32,886 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,894 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,895 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,896 INFO sqlalchemy.engine.Engine [cached since 0.1902s ago] ('район Свиблово',)
# 2023-06-16 00:32:32,898 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,903 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,904 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,905 INFO sqlalchemy.engine.Engine [cached since 0.1998s ago] ('район Зябликово',)
# 2023-06-16 00:32:32,908 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,916 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,917 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,918 INFO sqlalchemy.engine.Engine [cached since 0.2127s ago] ('Красносельский район',)
# 2023-06-16 00:32:32,920 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,928 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,929 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,930 INFO sqlalchemy.engine.Engine [cached since 0.2247s ago] ('Нагорный район',)
# 2023-06-16 00:32:32,932 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,937 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,938 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,938 INFO sqlalchemy.engine.Engine [cached since 0.233s ago] ('район Бибирево',)
# 2023-06-16 00:32:32,942 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,951 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,952 INFO sqlalchemy.engine.Engine [cached since 0.2465s ago] ('район Ново-Переделкино',)
# 2023-06-16 00:32:32,954 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,963 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,964 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,965 INFO sqlalchemy.engine.Engine [cached since 0.2594s ago] ('Даниловский район',)
# 2023-06-16 00:32:32,967 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:32,973 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:32,975 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:32,976 INFO sqlalchemy.engine.Engine [cached since 0.2711s ago] ('район Дорогомилово',)
# 2023-06-16 00:32:32,982 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,002 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,004 INFO sqlalchemy.engine.Engine [cached since 0.2987s ago] ('район Текстильщики',)
# 2023-06-16 00:32:33,008 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,015 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,016 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,017 INFO sqlalchemy.engine.Engine [cached since 0.3112s ago] ('Южнопортовый район',)
# 2023-06-16 00:32:33,019 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,026 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,027 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,028 INFO sqlalchemy.engine.Engine [cached since 0.3227s ago] ('район Марьино',)
# 2023-06-16 00:32:33,034 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,043 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,044 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,045 INFO sqlalchemy.engine.Engine [cached since 0.3395s ago] ('район Преображенское',)
# 2023-06-16 00:32:33,049 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,054 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,058 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,059 INFO sqlalchemy.engine.Engine [cached since 0.354s ago] ('район Филёвский Парк',)
# 2023-06-16 00:32:33,062 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,069 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,070 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,071 INFO sqlalchemy.engine.Engine [cached since 0.3654s ago] ('район Кунцево',)
# 2023-06-16 00:32:33,074 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,081 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,082 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,083 INFO sqlalchemy.engine.Engine [cached since 0.3773s ago] ('район Орехово-Борисово Южное',)
# 2023-06-16 00:32:33,085 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,090 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,092 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,092 INFO sqlalchemy.engine.Engine [cached since 0.3868s ago] ('район Хорошёво-Мнёвники',)
# 2023-06-16 00:32:33,094 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,100 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,101 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,102 INFO sqlalchemy.engine.Engine [cached since 0.3966s ago] ('район Новокосино',)
# 2023-06-16 00:32:33,105 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,112 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,114 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,114 INFO sqlalchemy.engine.Engine [cached since 0.4088s ago] ('Басманный район',)
# 2023-06-16 00:32:33,117 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,125 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,126 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,126 INFO sqlalchemy.engine.Engine [cached since 0.4212s ago] ('район Косино-Ухтомский',)
# 2023-06-16 00:32:33,130 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,145 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,146 INFO sqlalchemy.engine.Engine [cached since 0.4411s ago] ('Пресненский район',)
# 2023-06-16 00:32:33,149 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,160 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,162 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,162 INFO sqlalchemy.engine.Engine [cached since 0.4571s ago] ('район Митино',)
# 2023-06-16 00:32:33,164 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,172 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,174 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,175 INFO sqlalchemy.engine.Engine [cached since 0.4699s ago] ('район Чертаново Северное',)
# 2023-06-16 00:32:33,178 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,188 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,190 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,191 INFO sqlalchemy.engine.Engine [cached since 0.4859s ago] ('район Фили-Давыдково',)
# 2023-06-16 00:32:33,194 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,201 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,203 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,204 INFO sqlalchemy.engine.Engine [cached since 0.4983s ago] ('район Хамовники',)
# 2023-06-16 00:32:33,207 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,213 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,214 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,215 INFO sqlalchemy.engine.Engine [cached since 0.5095s ago] ('Мещанский район',)
# 2023-06-16 00:32:33,218 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,225 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,226 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,227 INFO sqlalchemy.engine.Engine [cached since 0.5218s ago] ('Головинский район',)
# 2023-06-16 00:32:33,230 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,236 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,238 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,240 INFO sqlalchemy.engine.Engine [cached since 0.5347s ago] ('район Раменки',)
# 2023-06-16 00:32:33,243 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,252 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,253 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,254 INFO sqlalchemy.engine.Engine [cached since 0.5486s ago] ('Таганский район',)
# 2023-06-16 00:32:33,258 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,264 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,265 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,266 INFO sqlalchemy.engine.Engine [cached since 0.5603s ago] ('район Чертаново Южное',)
# 2023-06-16 00:32:33,268 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,275 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,276 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,276 INFO sqlalchemy.engine.Engine [cached since 0.5709s ago] ('район Лефортово',)
# 2023-06-16 00:32:33,279 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,285 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,287 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,288 INFO sqlalchemy.engine.Engine [cached since 0.5824s ago] ('район Выхино-Жулебино',)
# 2023-06-16 00:32:33,292 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,299 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,299 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,300 INFO sqlalchemy.engine.Engine [cached since 0.5951s ago] ('район Покровское-Стрешнево',)
# 2023-06-16 00:32:33,304 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,320 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,323 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,326 INFO sqlalchemy.engine.Engine [cached since 0.6209s ago] ('Академический район',)
# 2023-06-16 00:32:33,329 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,337 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,337 INFO sqlalchemy.engine.Engine [cached since 0.6321s ago] ('район Строгино',)
# 2023-06-16 00:32:33,343 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,350 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,351 INFO sqlalchemy.engine.Engine [cached since 0.6453s ago] ('район Якиманка',)
# 2023-06-16 00:32:33,353 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,361 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,362 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,363 INFO sqlalchemy.engine.Engine [cached since 0.658s ago] ('поселение Внуковское',)
# 2023-06-16 00:32:33,365 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,374 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,375 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,377 INFO sqlalchemy.engine.Engine [cached since 0.6713s ago] ('район Нагатинский Затон',)
# 2023-06-16 00:32:33,380 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,388 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,390 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,394 INFO sqlalchemy.engine.Engine [cached since 0.6891s ago] ('район Ясенево',)
# 2023-06-16 00:32:33,398 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,406 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,409 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,410 INFO sqlalchemy.engine.Engine [cached since 0.7045s ago] ('район Сокол',)
# 2023-06-16 00:32:33,413 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,419 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,420 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,422 INFO sqlalchemy.engine.Engine [cached since 0.7165s ago] ('район Сокольники',)
# 2023-06-16 00:32:33,426 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,434 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,438 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,441 INFO sqlalchemy.engine.Engine [cached since 0.7355s ago] ('район Некрасовка',)
# 2023-06-16 00:32:33,443 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,452 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,453 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,453 INFO sqlalchemy.engine.Engine [cached since 0.7478s ago] ('район Аэропорт',)
# 2023-06-16 00:32:33,457 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,464 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,465 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,466 INFO sqlalchemy.engine.Engine [cached since 0.7611s ago] ('Алексеевский район',)
# 2023-06-16 00:32:33,470 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,477 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,478 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,479 INFO sqlalchemy.engine.Engine [cached since 0.7737s ago] ('район Северное Тушино',)
# 2023-06-16 00:32:33,482 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,492 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,493 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,494 INFO sqlalchemy.engine.Engine [cached since 0.7891s ago] ('район Северное Бутово',)
# 2023-06-16 00:32:33,497 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,504 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,506 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,508 INFO sqlalchemy.engine.Engine [cached since 0.8031s ago] ('район Крылатское',)
# 2023-06-16 00:32:33,513 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,520 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,523 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,525 INFO sqlalchemy.engine.Engine [cached since 0.8197s ago] ('район Южное Тушино',)
# 2023-06-16 00:32:33,527 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,535 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,536 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,537 INFO sqlalchemy.engine.Engine [cached since 0.8313s ago] ('район Тропарёво-Никулино',)
# 2023-06-16 00:32:33,538 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,547 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,548 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,550 INFO sqlalchemy.engine.Engine [cached since 0.8443s ago] ('район Перово',)
# 2023-06-16 00:32:33,552 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,564 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,565 INFO sqlalchemy.engine.Engine [cached since 0.8594s ago] ('район Щукино',)
# 2023-06-16 00:32:33,567 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,573 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,575 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,576 INFO sqlalchemy.engine.Engine [cached since 0.8711s ago] ('район Новогиреево',)
# 2023-06-16 00:32:33,580 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,593 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,596 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,597 INFO sqlalchemy.engine.Engine [cached since 0.8913s ago] ('район Чертаново Центральное',)
# 2023-06-16 00:32:33,600 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,609 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,611 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,611 INFO sqlalchemy.engine.Engine [cached since 0.9062s ago] ('район Марьина Роща',)
# 2023-06-16 00:32:33,618 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,627 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,628 INFO sqlalchemy.engine.Engine [cached since 0.9227s ago] ('район Братеево',)
# 2023-06-16 00:32:33,632 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,653 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,654 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,656 INFO sqlalchemy.engine.Engine [cached since 0.9512s ago] ('район Нагатино-Садовники',)
# 2023-06-16 00:32:33,661 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,757 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,758 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,759 INFO sqlalchemy.engine.Engine [cached since 1.054s ago] ('Бескудниковский район',)
# 2023-06-16 00:32:33,762 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,770 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,774 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,775 INFO sqlalchemy.engine.Engine [cached since 1.07s ago] ('район Солнцево',)
# 2023-06-16 00:32:33,778 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,784 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,786 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,786 INFO sqlalchemy.engine.Engine [cached since 1.081s ago] ('район Отрадное',)
# 2023-06-16 00:32:33,789 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,796 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,797 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,799 INFO sqlalchemy.engine.Engine [cached since 1.094s ago] ('Рязанский район',)
# 2023-06-16 00:32:33,802 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,808 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,810 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,811 INFO sqlalchemy.engine.Engine [cached since 1.105s ago] ('район Коньково',)
# 2023-06-16 00:32:33,814 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,821 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,822 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,822 INFO sqlalchemy.engine.Engine [cached since 1.118s ago] ('район Царицыно',)
# 2023-06-16 00:32:33,826 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,833 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,834 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,834 INFO sqlalchemy.engine.Engine [cached since 1.129s ago] ('Хорошёвский район',)
# 2023-06-16 00:32:33,836 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,841 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,842 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,843 INFO sqlalchemy.engine.Engine [cached since 1.137s ago] ('Войковский район',)
# 2023-06-16 00:32:33,846 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,853 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,854 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,854 INFO sqlalchemy.engine.Engine [cached since 1.149s ago] ('район Соколиная Гора',)
# 2023-06-16 00:32:33,857 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,864 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,865 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,865 INFO sqlalchemy.engine.Engine [cached since 1.16s ago] ('поселение Московский',)
# 2023-06-16 00:32:33,868 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,875 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,876 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,878 INFO sqlalchemy.engine.Engine [cached since 1.173s ago] ('район Орехово-Борисово Северное',)
# 2023-06-16 00:32:33,880 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,886 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,887 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,887 INFO sqlalchemy.engine.Engine [cached since 1.182s ago] ('район Москворечье-Сабурово',)
# 2023-06-16 00:32:33,889 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,896 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,896 INFO sqlalchemy.engine.Engine [cached since 1.191s ago] ('район Восточное Дегунино',)
# 2023-06-16 00:32:33,898 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,903 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,904 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,905 INFO sqlalchemy.engine.Engine [cached since 1.2s ago] ('район Левобережный',)
# 2023-06-16 00:32:33,907 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,914 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,915 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,915 INFO sqlalchemy.engine.Engine [cached since 1.21s ago] ('район Люблино',)
# 2023-06-16 00:32:33,917 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,923 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,924 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,925 INFO sqlalchemy.engine.Engine [cached since 1.22s ago] ('район Проспект Вернадского',)
# 2023-06-16 00:32:33,927 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,933 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,934 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,934 INFO sqlalchemy.engine.Engine [cached since 1.229s ago] ('район Богородское',)
# 2023-06-16 00:32:33,936 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,942 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,943 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,944 INFO sqlalchemy.engine.Engine [cached since 1.238s ago] ('район Тёплый Стан',)
# 2023-06-16 00:32:33,945 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,951 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,951 INFO sqlalchemy.engine.Engine [cached since 1.246s ago] ('Бабушкинский район',)
# 2023-06-16 00:32:33,953 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,961 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,961 INFO sqlalchemy.engine.Engine [cached since 1.256s ago] ('район Печатники',)
# 2023-06-16 00:32:33,963 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,968 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,969 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,970 INFO sqlalchemy.engine.Engine [cached since 1.265s ago] ('район Гольяново',)
# 2023-06-16 00:32:33,973 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,980 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,981 INFO sqlalchemy.engine.Engine [cached since 1.275s ago] ('район Ховрино',)
# 2023-06-16 00:32:33,983 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,989 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,990 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,990 INFO sqlalchemy.engine.Engine [cached since 1.285s ago] ('Гагаринский район',)
# 2023-06-16 00:32:33,992 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:33,997 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:33,998 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:33,998 INFO sqlalchemy.engine.Engine [cached since 1.293s ago] ('район Коптево',)
# 2023-06-16 00:32:34,000 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,007 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,008 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:34,008 INFO sqlalchemy.engine.Engine [cached since 1.303s ago] ('район Марфино',)
# 2023-06-16 00:32:34,010 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,016 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:34,017 INFO sqlalchemy.engine.Engine [cached since 1.312s ago] ('район Ростокино',)
# 2023-06-16 00:32:34,018 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,024 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,025 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:34,026 INFO sqlalchemy.engine.Engine [cached since 1.321s ago] ('район Очаково-Матвеевское',)
# 2023-06-16 00:32:34,028 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,033 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,034 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:34,034 INFO sqlalchemy.engine.Engine [cached since 1.329s ago] ('Савёловский район',)
# 2023-06-16 00:32:34,038 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,044 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,045 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:34,046 INFO sqlalchemy.engine.Engine [cached since 1.341s ago] ('поселение Сосенское',)
# 2023-06-16 00:32:34,048 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,054 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,055 INFO sqlalchemy.engine.Engine INSERT INTO district (district) VALUES (?)
# 2023-06-16 00:32:34,056 INFO sqlalchemy.engine.Engine [cached since 1.351s ago] ('Можайский район',)
# 2023-06-16 00:32:34,059 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,066 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,068 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,068 INFO sqlalchemy.engine.Engine [generated in 0.00076s] ('Тимирязевская', 1058907003)
# 2023-06-16 00:32:34,071 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,078 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,079 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,079 INFO sqlalchemy.engine.Engine [cached since 0.01123s ago] ('Дмитровская', 1058996666)
# 2023-06-16 00:32:34,081 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,086 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,087 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,088 INFO sqlalchemy.engine.Engine [cached since 0.02005s ago] ('Белорусская', 1058906594)
# 2023-06-16 00:32:34,090 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,096 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,097 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,098 INFO sqlalchemy.engine.Engine [cached since 0.03014s ago] ('Каланчевская', 1059233585)
# 2023-06-16 00:32:34,100 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,109 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,110 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,111 INFO sqlalchemy.engine.Engine [cached since 0.04278s ago] ('Текстильщики', 1059235328)
# 2023-06-16 00:32:34,119 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,129 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,130 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,131 INFO sqlalchemy.engine.Engine [cached since 0.06296s ago] ('Фили', 1058903042)
# 2023-06-16 00:32:34,135 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,156 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,158 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,159 INFO sqlalchemy.engine.Engine [cached since 0.09072s ago] ('Кунцевская', 1058901824)
# 2023-06-16 00:32:34,163 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,174 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,175 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,176 INFO sqlalchemy.engine.Engine [cached since 0.1083s ago] ('Курская', 1059233904)
# 2023-06-16 00:32:34,180 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,189 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,191 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,191 INFO sqlalchemy.engine.Engine [cached since 0.1234s ago] ('Тестовская', 1058903381)
# 2023-06-16 00:32:34,195 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,201 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,202 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,203 INFO sqlalchemy.engine.Engine [cached since 0.1353s ago] ('Беговая', 1058905211)
# 2023-06-16 00:32:34,207 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,216 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,217 INFO sqlalchemy.engine.Engine [cached since 0.1493s ago] ('Савеловская', 1058906777)
# 2023-06-16 00:32:34,220 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,229 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,230 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,231 INFO sqlalchemy.engine.Engine [cached since 0.1633s ago] ('Волоколамская', 1058982846)
# 2023-06-16 00:32:34,233 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,240 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,241 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# 2023-06-16 00:32:34,241 INFO sqlalchemy.engine.Engine [cached since 0.1736s ago] ('Курская', 1059233904)
# 2023-06-16 00:32:34,244 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-16 00:32:34,250 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:34,251 INFO sqlalchemy.engine.Engine INSERT INTO mcd (name, global_id) VALUES (?, ?)
# ...
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), (SELECT mcd.id
# FROM mcd
# WHERE mcd.name = ?), (SELECT aeroexpress.id
# FROM aeroexpress
# WHERE aeroexpress.name = ?), (SELECT railway.id
# FROM railway
# WHERE railway.name = ?), ?, ?)
# 2023-06-16 00:32:39,692 INFO sqlalchemy.engine.Engine [cached since 3.625s ago] (300, 'Шелепиха', 'Большая кольцевая линия', 'Центральный административный округ', 'Пресненский район', 'Тестовская', 'Тестовская', 'Тестовская', 'действует', 696749112)
# 2023-06-16 00:32:39,694 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,701 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,702 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,703 INFO sqlalchemy.engine.Engine [cached since 4.007s ago] (301, 'Озёрная', 'Солнцевская линия', 'Западный административный округ', 'район Очаково-Матвеевское', None, None, None, 'действует', 886123736)
# 2023-06-16 00:32:39,707 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,714 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,715 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,717 INFO sqlalchemy.engine.Engine [cached since 4.021s ago] (302, 'Говорово', 'Солнцевская линия', 'Западный административный округ', 'район Солнцево', None, None, None, 'действует', 886123738)
# 2023-06-16 00:32:39,720 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,728 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,729 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,730 INFO sqlalchemy.engine.Engine [cached since 4.034s ago] (303, 'Беломорская', 'Замоскворецкая линия', 'Северный административный округ', 'район Левобережный', None, None, None, 'действует', 904474367)
# 2023-06-16 00:32:39,732 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,740 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,741 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,742 INFO sqlalchemy.engine.Engine [cached since 4.046s ago] (304, 'Зорге', 'Московское центральное кольцо', 'Северо-Западный административный округ', 'район Хорошёво-Мнёвники', None, None, None, 'действует', 905932318)
# 2023-06-16 00:32:39,744 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,779 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,781 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,783 INFO sqlalchemy.engine.Engine [cached since 4.087s ago] (305, 'Панфиловская', 'Московское центральное кольцо', 'Северо-Западный административный округ', 'район Щукино', None, None, None, 'действует', 905932372)
# 2023-06-16 00:32:39,791 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,799 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,800 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,801 INFO sqlalchemy.engine.Engine [cached since 4.105s ago] (306, 'Коптево', 'Московское центральное кольцо', 'Северный административный округ', 'район Коптево', None, None, None, 'действует', 905932373)
# 2023-06-16 00:32:39,802 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,809 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,811 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), (SELECT mcd.id
# FROM mcd
# WHERE mcd.name = ?), (SELECT aeroexpress.id
# FROM aeroexpress
# WHERE aeroexpress.name = ?), (SELECT railway.id
# FROM railway
# WHERE railway.name = ?), ?, ?)
# 2023-06-16 00:32:39,812 INFO sqlalchemy.engine.Engine [cached since 3.745s ago] (307, 'Савёловская', 'Большая кольцевая линия', 'Северный административный округ', 'Савёловский район', 'Савеловская', 'Савеловский вокзал', 'Савёловская', 'действует', 906044097)
# 2023-06-16 00:32:39,814 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,821 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,822 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,823 INFO sqlalchemy.engine.Engine [cached since 4.127s ago] (308, 'Филатов луг', 'Сокольническая линия', 'Новомосковский административный округ', 'поселение Сосенское', None, None, None, 'действует', 930063626)
# 2023-06-16 00:32:39,825 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,831 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,833 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,833 INFO sqlalchemy.engine.Engine [cached since 4.138s ago] (309, 'Прокшино', 'Сокольническая линия', 'Новомосковский административный округ', 'поселение Сосенское', None, None, None, 'действует', 930063627)
# 2023-06-16 00:32:39,835 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,843 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,845 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,845 INFO sqlalchemy.engine.Engine [cached since 4.15s ago] (310, 'Ольховая', 'Сокольническая линия', 'Новомосковский административный округ', 'поселение Сосенское', None, None, None, 'действует', 930063628)
# 2023-06-16 00:32:39,847 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,861 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,862 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,863 INFO sqlalchemy.engine.Engine [cached since 4.167s ago] (311, 'Коммунарка', 'Сокольническая линия', 'Новомосковский административный округ', 'поселение Сосенское', None, None, None, 'действует', 930063629)
# 2023-06-16 00:32:39,865 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,872 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,873 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,874 INFO sqlalchemy.engine.Engine [cached since 4.179s ago] (315, 'Лефортово', 'Большая кольцевая линия', 'Юго-Восточный административный округ', 'район Лефортово', None, None, None, 'действует', 1045820903)
# 2023-06-16 00:32:39,876 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,883 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,885 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,885 INFO sqlalchemy.engine.Engine [cached since 4.19s ago] (312, 'Зюзино', 'Большая кольцевая линия', 'Юго-Западный административный округ', 'район Зюзино', None, None, None, 'действует', 1045820911)
# 2023-06-16 00:32:39,888 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,919 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,922 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,923 INFO sqlalchemy.engine.Engine [cached since 4.228s ago] (316, 'Народное Ополчение', 'Большая кольцевая линия', 'Северо-Западный административный округ', 'район Хорошёво-Мнёвники', None, None, None, 'действует', 1103704696)
# 2023-06-16 00:32:39,925 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,945 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,947 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:39,948 INFO sqlalchemy.engine.Engine [cached since 4.253s ago] (318, 'Давыдково', 'Большая кольцевая линия', 'Западный административный округ', 'Можайский район', None, None, None, 'действует', 1266781625)
# 2023-06-16 00:32:39,950 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:39,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:39,960 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, (SELECT railway.id
# FROM railway
# WHERE railway.name = ?), ?, ?)
# 2023-06-16 00:32:39,961 INFO sqlalchemy.engine.Engine [cached since 3.944s ago] (318, 'Аминьевская', 'Большая кольцевая линия', 'Западный административный округ', 'район Очаково-Матвеевское', None, None, 'Аминьевская', 'действует', 1266781654)
# 2023-06-16 00:32:39,963 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:40,005 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:40,006 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:40,007 INFO sqlalchemy.engine.Engine [cached since 4.312s ago] (320, 'Новаторская', 'Большая кольцевая линия', 'Юго-Западный административный округ', 'Обручевский район', None, None, None, 'действует', 1266781655)
# 2023-06-16 00:32:40,009 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:40,017 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:40,018 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, (SELECT railway.id
# FROM railway
# WHERE railway.name = ?), ?, ?)
# 2023-06-16 00:32:40,019 INFO sqlalchemy.engine.Engine [cached since 4.002s ago] (321, 'Варшавская', 'Большая кольцевая линия', 'Южный административный округ', 'район Москворечье-Сабурово', None, None, 'Варшавская', 'действует', 2373307655)
# 2023-06-16 00:32:40,022 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:40,029 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:40,031 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), (SELECT mcd.id
# FROM mcd
# WHERE mcd.name = ?), ?, (SELECT railway.id
# FROM railway
# WHERE railway.name = ?), ?, ?)
# 2023-06-16 00:32:40,032 INFO sqlalchemy.engine.Engine [cached since 4.17s ago] (322, 'Марьина Роща', 'Большая кольцевая линия', 'Северо-Восточный административный округ', 'район Марьина Роща', 'Марьина Роща', None, 'Марьина Роща', 'действует', 2536249332)
# 2023-06-16 00:32:40,036 INFO sqlalchemy.engine.Engine COMMIT
# SELECT line.id
# FROM line
# WHERE line.line = :line_1
# 2023-06-16 00:32:40,044 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-16 00:32:40,046 INFO sqlalchemy.engine.Engine INSERT INTO station (dataset_id, station, line_id, adm_area, district_id, mcd_id, aeroexpress_id, railway_id, status, global_id) VALUES (?, ?, (SELECT line.id
# FROM line
# WHERE line.line = ?), ?, (SELECT district.id
# FROM district
# WHERE district.district = ?), ?, ?, ?, ?, ?)
# 2023-06-16 00:32:40,047 INFO sqlalchemy.engine.Engine [cached since 4.352s ago] (323, 'Кленовый бульвар', 'Большая кольцевая линия', 'Южный административный округ', 'район Нагатинский Затон', None, None, None, 'действует', 2536249481)
# 2023-06-16 00:32:40,051 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    # Все станции, id в датасете которых больше ста и которые располагаются на солнцевской линии
    print(session.query(Station).filter(and_(Station.dataset_id > 100, Station.line_id == select(Line.id).where(Line.line == 'Солнцевская линия').scalar_subquery())).all())

    # Все станции, у которых есть выход на мцд, аэроэкспресс и ж\д станцию
    print(session.query(Station).filter(and_(Station.mcd_id != None, Station.aeroexpress_id != None, Station.railway_id != None)).all())

    # Все действующие станции в районе Арбат на Арбатско-Покровской линии в ЦАО
    print(session.query(Station).filter(and_(Station.status == 'действует', Station.district_id == select(District.id).where(District.district == 'район Арбат').scalar_subquery(), Station.line_id == select(Line.id).where(Line.line == 'Арбатско-Покровская линия').scalar_subquery(), Station.adm_area == 'Центральный административный округ')).all())

     # Все действующие станции в ЦАО с ж\д станциями
    print(session.query(Station).filter(and_(Station.status == 'действует', Station.adm_area == 'Центральный административный округ', Station.railway_id != None)).all())

     # Все станции МЦД, Аэроэкспресса и Ж/Д, когда они все на одной станции метро
    print(session.query(Station, MCD, AeroExpress, RailwayStation).filter(and_(Station.mcd_id == MCD.id, Station.aeroexpress_id == AeroExpress.id, Station.railway_id == RailwayStation.id)).all())
# Out:
# [Station name: Плющиха, Station name: Новопеределкино, Station name: Дорогомиловская, Station name: Третьяковская, Station name: Парк Победы, Station name: Ломоносовский проспект, Station name: Боровское шоссе, Station name: Рассказовка, Station name: Мичуринский проспект, Station name: Деловой центр, Station name: Минская, Station name: Солнцево, Station name: Волхонка, Station name: Раменки, Station name: Озёрная, Station name: Говорово]
# [Station name: Белорусская, Station name: Фили, Station name: Кунцевская, Station name: Международная, Station name: Беговая, Station name: Савёловская, Station name: Деловой центр, Station name: Белорусская, Station name: Окружная, Station name: Кунцевская, Station name: Деловой центр, Station name: Славянский бульвар, Station name: Кунцевская, Station name: Выставочная, Station name: Шелепиха, Station name: Деловой центр, Station name: Окружная, Station name: Шелепиха, Station name: Савёловская]
# [Station name: Арбатская, Station name: Смоленская]
# [Station name: Павелецкая, Station name: Белорусская, Station name: Комсомольская, Station name: Павелецкая, Station name: Курская, Station name: Международная, Station name: Беговая, Station name: Чкаловская, Station name: Площадь Ильича, Station name: Рижская, Station name: Деловой центр, Station name: Белорусская, Station name: Курская, Station name: Деловой центр, Station name: Комсомольская, Station name: Выставочная, Station name: Рижская, Station name: Римская, Station name: Шелепиха, Station name: Деловой центр, Station name: Шелепиха]
# [(Station name: Белорусская, MCD station name: Белорусская, Aeroexpress station name: Белорусский вокзал, Railway station name: Белорусская), (Station name: Фили, MCD station name: Фили, Aeroexpress station name: Фили, Railway station name: Фили), (Station name: Кунцевская, MCD station name: Кунцевская, Aeroexpress station name: Кунцевская, Railway station name: Кунцевская), (Station name: Международная, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Беговая, MCD station name: Беговая, Aeroexpress station name: Беговая, Railway station name: Беговая), (Station name: Савёловская, MCD station name: Савеловская, Aeroexpress station name: Савеловский вокзал, Railway station name: Савёловская), (Station name: Деловой центр, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Белорусская, MCD station name: Белорусская, Aeroexpress station name: Белорусский вокзал, Railway station name: Белорусская), (Station name: Окружная, MCD station name: Окружная, Aeroexpress station name: Окружная, Railway station name: Окружная), (Station name: Кунцевская, MCD station name: Кунцевская, Aeroexpress station name: Кунцевская, Railway station name: Кунцевская), (Station name: Деловой центр, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Славянский бульвар, MCD station name: Славянский бульвар, Aeroexpress station name: Славянский бульвар, Railway station name: Славянский бульвар), (Station name: Кунцевская, MCD station name: Кунцевская, Aeroexpress station name: Кунцевская, Railway station name: Кунцевская), (Station name: Выставочная, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Шелепиха, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Деловой центр, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Окружная, MCD station name: Окружная, Aeroexpress station name: Окружная, Railway station name: Окружная), (Station name: Шелепиха, MCD station name: Тестовская, Aeroexpress station name: Тестовская, Railway station name: Тестовская), (Station name: Савёловская, MCD station name: Савеловская, Aeroexpress station name: Савеловский вокзал, Railway station name: Савёловская)]
